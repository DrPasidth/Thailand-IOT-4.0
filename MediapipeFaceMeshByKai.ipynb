# %% [markdown]
# <a href="https://colab.research.google.com/github/DrPasidth/Thailand-IOT-4.0/blob/master/MediapipeFaceMeshByKai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
# !pip install mediapipe
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 21.6 MB/s eta 0:00:00
# ...

# %%
import mediapipe as mp

# %%
mpFaceMesh = mp.solutions.face_mesh

# %%
faceMesh = mpFaceMesh.FaceMesh(max_num_faces=2)

# %%
mpDraw = mp.solutions.drawing_utils

# %%
image = cv2.imread("/content/FaceMesh.jpg")

# %%
image.shape
# Out:
# (300, 600, 3)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300>

# %%
imageRGB = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
results = faceMesh.process(imageRGB)

# %%
results.multi_face_landmarks
# Out:
# [landmark {
#    x: 0.28865161538124084
#    y: 0.6134734153747559
#    z: -0.02152974344789982
#  }
#  landmark {
#    x: 0.2970161736011505
#    y: 0.5569572448730469
#    z: -0.04663277044892311
#  }
#  landmark {
#    x: 0.29136568307876587
#    y: 0.5731019377708435
#    z: -0.022858064621686935
#  }
#  landmark {
#    x: 0.2894067168235779
#    y: 0.4906614124774933
#    z: -0.03911397233605385
#  }
#  landmark {
#    x: 0.2983582615852356
#    y: 0.5376986861228943
#    z: -0.05036068707704544
#  }
#  landmark {
#    x: 0.29821884632110596
#    y: 0.5110794901847839
#    z: -0.047760605812072754
#  }
#  landmark {
#    x: 0.29583069682121277
#    y: 0.4455260634422302
#    z: -0.02657143957912922
#  }
#  landmark {
#    x: 0.22277094423770905
#    y: 0.42559826374053955
#    z: -0.005765125621110201
#  }
#  landmark {
#    x: 0.2964083254337311
#    y: 0.3951340913772583
#    z: -0.022293297573924065
#  }
#  landmark {
#    x: 0.2978479862213135
#    y: 0.368855357170105
# ...

# %%
if results.multi_face_landmarks:
  for faceLms in results.multi_face_landmarks:
    mpDraw.draw_landmarks(imageRGB,faceLms)

# %%
cv2_imshow(imageRGB)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300>

# %%
imageBGR = cv2.cvtColor(imageRGB,cv2.COLOR_RGB2BGR)
cv2_imshow(imageBGR)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300>

# %% [markdown]
# ![facemesh_place.jpg](data:image/jpeg;base64,...)

# %%
if results.multi_face_landmarks:
  for faceLms in results.multi_face_landmarks:
    mpDraw.draw_landmarks(imageRGB,faceLms,mpFaceMesh.FACEMESH_TESSELATION)

# %%
imageBGR = cv2.cvtColor(imageRGB,cv2.COLOR_RGB2BGR)
cv2_imshow(imageBGR)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300>

# %%
if results.multi_face_landmarks:
  for faceLms in results.multi_face_landmarks:
    mpDraw.draw_landmarks(imageRGB,faceLms,mpFaceMesh.FACEMESH_TESSELATION)
    for lm in faceLms.landmark:
      print(lm)
# Out:
# x: 0.28865161538124084
# y: 0.6134734153747559
# z: -0.02152974344789982
#
# x: 0.2970161736011505
# y: 0.5569572448730469
# z: -0.04663277044892311
#
# x: 0.29136568307876587
# y: 0.5731019377708435
# z: -0.022858064621686935
#
# x: 0.2894067168235779
# y: 0.4906614124774933
# z: -0.03911397233605385
#
# x: 0.2983582615852356
# y: 0.5376986861228943
# z: -0.05036068707704544
#
# x: 0.29821884632110596
# y: 0.5110794901847839
# z: -0.047760605812072754
#
# x: 0.29583069682121277
# y: 0.4455260634422302
# z: -0.02657143957912922
#
# x: 0.22277094423770905
# y: 0.42559826374053955
# z: -0.005765125621110201
#
# x: 0.2964083254337311
# y: 0.3951340913772583
# z: -0.022293297573924065
#
# x: 0.2978479862213135
# y: 0.368855357170105
# z: -0.0254222359508276
#
# x: 0.2995736598968506
# y: 0.2759418487548828
# z: -0.020659644156694412
#
# x: 0.2878393828868866
# y: 0.621888279914856
# z: -0.019993340596556664
#
# x: 0.2867656350135803
# y: 0.6272472143173218
# z: -0.016796259209513664
#
# ...

# %%
if results.multi_face_landmarks:
  for faceLms in results.multi_face_landmarks:
    mpDraw.draw_landmarks(imageRGB,faceLms,mpFaceMesh.FACEMESH_TESSELATION)
    for id,lm in enumerate(faceLms.landmark):
      #print(lm)
      h,w,c = image.shape
      x,y = int(lm.x*w),int(lm.y*h)
      print(id,x,y)
# Out:
# 0 173 184
# 1 178 167
# 2 174 171
# 3 173 147
# 4 179 161
# 5 178 153
# 6 177 133
# 7 133 127
# 8 177 118
# 9 178 110
# 10 179 82
# 11 172 186
# 12 172 188
# 13 171 188
# 14 171 189
# 15 171 191
# 16 171 194
# 17 170 196
# 18 169 201
# 19 177 169
# 20 171 168
# 21 109 101
# 22 150 134
# 23 144 134
# 24 138 133
# 25 131 129
# 26 155 133
# 27 144 118
# 28 150 119
# 29 138 119
# 30 134 120
# 31 126 132
# 32 147 209
# 33 131 125
# 34 105 126
# 35 119 127
# 36 145 158
# 37 166 182
# 38 166 187
# 39 158 183
# 40 153 184
# 41 160 187
# 42 155 186
# 43 144 190
# 44 173 166
# 45 173 160
# 46 125 113
# 47 158 144
# 48 159 163
# 49 158 160
# 50 127 155
# 51 173 153
# 52 141 108
# 53 132 110
# 54 117 92
# 55 166 116
# 56 155 122
# 57 140 185
# 58 104 179
# 59 162 166
# 60 167 168
# 61 146 185
# 62 148 185
# 63 129 105
# 64 158 165
# 65 152 110
# 66 151 105
# 67 146 81
# 68 123 98
# 69 149 93
# 70 121 110
# 71 115 106
# 72 166 185
# 73 159 185
# 74 154 185
# 75 163 167
# 76 147 185
# 77 150 187
# ...

# %%
imageBGR = cv2.cvtColor(imageRGB,cv2.COLOR_RGB2BGR)
cv2_imshow(imageBGR)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300>

# %%
image = cv2.imread("/content/FaceMesh.jpg")
imageRGB = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)


if results.multi_face_landmarks:
  for faceLms in results.multi_face_landmarks:

    for id,lm in enumerate(faceLms.landmark):
    #  print(lm)

      if id == 0:
        h,w,c = image.shape
        x,y = int(lm.x*w),int(lm.y*h)
        print(id,x,y)

        cv2.circle(imageRGB,(x,y),3,(255,255,255),-1)

imageBGR = cv2.cvtColor(imageRGB,cv2.COLOR_RGB2BGR)
cv2_imshow(imageBGR)
# Out:
# 0 173 184
# 0 437 159
# <PIL.Image.Image image mode=RGB size=600x300>

# %%
image = cv2.imread("/content/FaceMesh.jpg")
imageRGB = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)


if results.multi_face_landmarks:
  for faceLms in results.multi_face_landmarks:

    for id,lm in enumerate(faceLms.landmark):
    #  print(lm)
      for i in range(0,10):
        if id == i:
          h,w,c = image.shape
          x,y = int(lm.x*w),int(lm.y*h)
          print(id,x,y)

          cv2.circle(imageRGB,(x,y),3,(255,255,255),-1)

imageBGR = cv2.cvtColor(imageRGB,cv2.COLOR_RGB2BGR)
cv2_imshow(imageBGR)
# Out:
# 0 173 184
# 1 178 167
# 2 174 171
# 3 173 147
# 4 179 161
# 5 178 153
# 6 177 133
# 7 133 127
# 8 177 118
# 9 178 110
# 0 437 159
# 1 437 141
# 2 437 146
# 3 433 123
# 4 437 136
# 5 437 129
# 6 437 110
# 7 402 105
# 8 438 96
# 9 438 88
# <PIL.Image.Image image mode=RGB size=600x300>
