# %% [markdown]
# <a href="https://colab.research.google.com/github/DrPasidth/Thailand-IOT-4.0/blob/master/MediapipeHandsByKai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
# !pip install mediapipe
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 11.8 MB/s eta 0:00:00
# ...

# %%
import mediapipe as mp

# %%
mpHands = mp.solutions.hands

# %%
hands = mpHands.Hands()

# %%
mpDraw = mp.solutions.drawing_utils

# %%
image = cv2.imread("Hands.jpg")

# %%
image.shape
# Out:
# (427, 640, 3)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
imageRGB = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
results = hands.process(imageRGB)

# %%
results.multi_hand_landmarks
# Out:
# [landmark {
#    x: 0.21979600191116333
#    y: 0.8080800771713257
#    z: 6.657677431576303e-07
#  }
#  landmark {
#    x: 0.313254714012146
#    y: 0.7443699836730957
#    z: -0.04941071569919586
#  }
#  landmark {
#    x: 0.38993018865585327
#    y: 0.658867597579956
#    z: -0.06758841127157211
#  }
#  landmark {
#    x: 0.4390668272972107
#    y: 0.5643441081047058
#    z: -0.08087312430143356
#  }
#  landmark {
#    x: 0.4311736822128296
#    y: 0.4749906659126282
#    z: -0.09286197274923325
#  }
#  landmark {
#    x: 0.3021194040775299
#    y: 0.4464770257472992
#    z: -0.030429380014538765
#  }
#  landmark {
#    x: 0.31612467765808105
#    y: 0.2975342571735382
#    z: -0.054245878010988235
#  }
#  landmark {
#    x: 0.3204910159111023
#    y: 0.20931649208068848
#    z: -0.07778485864400864
#  }
#  landmark {
#    x: 0.3224959373474121
#    y: 0.13039228320121765
#    z: -0.09541293978691101
#  }
#  landmark {
#    x: 0.24435898661613464
#    y: 0.431765079498291
# ...

# %%
if results.multi_hand_landmarks:
  for handLms in results.multi_hand_landmarks:
    mpDraw.draw_landmarks(imageRGB,handLms)

# %%
cv2_imshow(imageRGB)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
imageBGR = cv2.cvtColor(imageRGB,cv2.COLOR_RGB2BGR)
cv2_imshow(imageBGR)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
if results.multi_hand_landmarks:
  for handLms in results.multi_hand_landmarks:
    mpDraw.draw_landmarks(imageRGB,handLms,mpHands.HAND_CONNECTIONS)

# %%
imageBGR = cv2.cvtColor(imageRGB,cv2.COLOR_RGB2BGR)
cv2_imshow(imageBGR)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
if results.multi_hand_landmarks:
  for handLms in results.multi_hand_landmarks:
    for id,lm in enumerate(handLms.landmark):
      print(id,lm)
    mpDraw.draw_landmarks(imageRGB,handLms,mpHands.HAND_CONNECTIONS)
# Out:
# 0 x: 0.21979600191116333
# y: 0.8080800771713257
# z: 6.657677431576303e-07
#
# 1 x: 0.313254714012146
# y: 0.7443699836730957
# z: -0.04941071569919586
#
# 2 x: 0.38993018865585327
# y: 0.658867597579956
# z: -0.06758841127157211
#
# 3 x: 0.4390668272972107
# y: 0.5643441081047058
# z: -0.08087312430143356
#
# 4 x: 0.4311736822128296
# y: 0.4749906659126282
# z: -0.09286197274923325
#
# 5 x: 0.3021194040775299
# y: 0.4464770257472992
# z: -0.030429380014538765
#
# 6 x: 0.31612467765808105
# y: 0.2975342571735382
# z: -0.054245878010988235
#
# 7 x: 0.3204910159111023
# y: 0.20931649208068848
# z: -0.07778485864400864
#
# 8 x: 0.3224959373474121
# y: 0.13039228320121765
# z: -0.09541293978691101
#
# 9 x: 0.24435898661613464
# y: 0.431765079498291
# z: -0.024671269580721855
#
# 10 x: 0.2429969310760498
# y: 0.26899755001068115
# z: -0.04643263667821884
#
# 11 x: 0.24062751233577728
# y: 0.1646435260772705
# z: -0.07231449335813522
#
# 12 x: 0.23668017983436584
# y: 0.08054518699645996
# ...

# %%
if results.multi_hand_landmarks:
  for handLms in results.multi_hand_landmarks:
    for id,lm in enumerate(handLms.landmark):
      h,w,c = image.shape
      cx,cy = int(lm.x*w),int(lm.y*h)
      print(id,cx,cy)
    mpDraw.draw_landmarks(imageRGB,handLms,mpHands.HAND_CONNECTIONS)
# Out:
# 0 140 345
# 1 200 317
# 2 249 281
# 3 281 240
# 4 275 202
# 5 193 190
# 6 202 127
# 7 205 89
# 8 206 55
# 9 156 184
# 10 155 114
# 11 154 70
# 12 151 34
# 13 121 192
# 14 115 128
# 15 113 88
# 16 112 56
# 17 86 210
# 18 75 162
# 19 68 130
# 20 63 100
# 0 496 362
# 1 431 329
# 2 394 286
# 3 364 241
# 4 332 213
# 5 455 221
# 6 449 142
# 7 446 96
# 8 448 59
# 9 497 218
# 10 498 133
# 11 499 78
# 12 502 37
# 13 532 226
# 14 540 152
# 15 545 101
# 16 548 63
# 17 560 238
# 18 574 178
# 19 582 141
# 20 587 108

# %% [markdown]
# ![hand_landmarks.png](data:image/png;base64,...)

# %%
imageBGR = cv2.cvtColor(imageRGB,cv2.COLOR_RGB2BGR)
cv2_imshow(imageBGR)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
if results.multi_hand_landmarks:
  for handLms in results.multi_hand_landmarks:
    for id,lm in enumerate(handLms.landmark):
      h,w,c = image.shape
      cx,cy = int(lm.x*w),int(lm.y*h)
      print(id,cx,cy)
      if id == 0:
        cv2.circle(imageRGB,(cx,cy),25,(255,0,255),cv2.FILLED)
    mpDraw.draw_landmarks(imageRGB,handLms,mpHands.HAND_CONNECTIONS)
# Out:
# 0 140 345
# 1 200 317
# 2 249 281
# 3 281 240
# 4 275 202
# 5 193 190
# 6 202 127
# 7 205 89
# 8 206 55
# 9 156 184
# 10 155 114
# 11 154 70
# 12 151 34
# 13 121 192
# 14 115 128
# 15 113 88
# 16 112 56
# 17 86 210
# 18 75 162
# 19 68 130
# 20 63 100
# 0 496 362
# 1 431 329
# 2 394 286
# 3 364 241
# 4 332 213
# 5 455 221
# 6 449 142
# 7 446 96
# 8 448 59
# 9 497 218
# 10 498 133
# 11 499 78
# 12 502 37
# 13 532 226
# 14 540 152
# 15 545 101
# 16 548 63
# 17 560 238
# 18 574 178
# 19 582 141
# 20 587 108

# %%
imageBGR = cv2.cvtColor(imageRGB,cv2.COLOR_RGB2BGR)
cv2_imshow(imageBGR)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>
