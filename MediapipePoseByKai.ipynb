# %% [markdown]
# <a href="https://colab.research.google.com/github/DrPasidth/Thailand-IOT-4.0/blob/master/MediapipePoseByKai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
# !pip install mediapipe
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 15.8 MB/s eta 0:00:00
# ...

# %%
import mediapipe as mp

# %%
mpPose = mp.solutions.pose

# %%
pose = mpPose.Pose()

# %%
mpDraw = mp.solutions.drawing_utils

# %%
image = cv2.imread("Pose.jpg")

# %%
image.shape
# Out:
# (427, 640, 3)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
imageRGB = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
results = pose.process(imageRGB)

# %%
results.pose_landmarks
# Out:
# landmark {
#   x: 0.31730544567108154
#   y: 0.3551768660545349
#   z: -0.18553796410560608
#   visibility: 0.9998425245285034
# }
# landmark {
#   x: 0.309251993894577
#   y: 0.3417307436466217
#   z: -0.14981842041015625
#   visibility: 0.9995347261428833
# }
# landmark {
#   x: 0.3112109899520874
#   y: 0.33521729707717896
#   z: -0.1498798131942749
#   visibility: 0.9996022582054138
# }
# landmark {
#   x: 0.3133164942264557
#   y: 0.3283781409263611
#   z: -0.1498313695192337
#   visibility: 0.9995163679122925
# }
# landmark {
#   x: 0.3056195080280304
#   y: 0.3632446229457855
#   z: -0.14985230565071106
#   visibility: 0.9997500777244568
# }
# landmark {
#   x: 0.30549368262290955
#   y: 0.37142273783683777
#   z: -0.14993365108966827
#   visibility: 0.9998032450675964
# }
# landmark {
#   x: 0.3054233193397522
#   y: 0.3792676329612732
#   z: -0.14999929070472717
#   visibility: 0.9998143315315247
# }
# landmark {
#   x: 0.32875457406044006
#   y: 0.3221829831600189
# ...

# %%
if results.pose_landmarks:
  mpDraw.draw_landmarks(imageRGB,results.pose_landmarks)

# %%
cv2_imshow(imageRGB)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
imageBGR = cv2.cvtColor(imageRGB,cv2.COLOR_RGB2BGR)

# %%
cv2_imshow(imageBGR)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
if results.pose_landmarks:
  mpDraw.draw_landmarks(imageRGB,results.pose_landmarks,mpPose.POSE_CONNECTIONS)

# %%
imageBGR = cv2.cvtColor(imageRGB,cv2.COLOR_RGB2BGR)
cv2_imshow(imageBGR)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
if results.pose_landmarks:
  mpDraw.draw_landmarks(imageRGB,results.pose_landmarks,mpPose.POSE_CONNECTIONS)
  for id,lm in enumerate(results.pose_landmarks.landmark):
    h,w,c = imageRGB.shape
    print(id,lm)
# Out:
# 0 x: 0.31730544567108154
# y: 0.3551768660545349
# z: -0.18553796410560608
# visibility: 0.9998425245285034
#
# 1 x: 0.309251993894577
# y: 0.3417307436466217
# z: -0.14981842041015625
# visibility: 0.9995347261428833
#
# 2 x: 0.3112109899520874
# y: 0.33521729707717896
# z: -0.1498798131942749
# visibility: 0.9996022582054138
#
# 3 x: 0.3133164942264557
# y: 0.3283781409263611
# z: -0.1498313695192337
# visibility: 0.9995163679122925
#
# 4 x: 0.3056195080280304
# y: 0.3632446229457855
# z: -0.14985230565071106
# visibility: 0.9997500777244568
#
# 5 x: 0.30549368262290955
# y: 0.37142273783683777
# z: -0.14993365108966827
# visibility: 0.9998032450675964
#
# 6 x: 0.3054233193397522
# y: 0.3792676329612732
# z: -0.14999929070472717
# visibility: 0.9998143315315247
#
# 7 x: 0.32875457406044006
# y: 0.3221829831600189
# z: -0.01101521123200655
# visibility: 0.9991232752799988
#
# 8 x: 0.3184714913368225
# y: 0.39605462551116943
# z: -0.015277552418410778
# ...

# %%
if results.pose_landmarks:
  mpDraw.draw_landmarks(imageRGB,results.pose_landmarks,mpPose.POSE_CONNECTIONS)
  for id,lm in enumerate(results.pose_landmarks.landmark):
    h,w,c = imageRGB.shape
   # print(id,lm)
    cx,cy = int(lm.x*w) , int(lm.y*h)
    print(id,cx,cy)
# Out:
# 0 203 151
# 1 197 145
# 2 199 143
# 3 200 140
# 4 195 155
# 5 195 158
# 6 195 161
# 7 210 137
# 8 203 169
# 9 216 147
# 10 212 160
# 11 262 120
# 12 261 215
# 13 211 84
# 14 267 296
# 15 156 54
# 16 258 364
# 17 137 48
# 18 245 374
# 19 136 51
# 20 243 375
# 21 143 54
# 22 249 372
# 23 407 190
# 24 371 238
# 25 491 268
# 26 465 304
# 27 573 352
# 28 562 362
# 29 590 368
# 30 581 373
# 31 581 368
# 32 561 377

# %%
imageBGR = cv2.cvtColor(imageRGB,cv2.COLOR_RGB2BGR)
cv2_imshow(imageBGR)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %% [markdown]
# ![pose_tracking_full_body_landmarks.png](data:image/png;base64,...)
